# %% [markdown]
# ##
# 1.) Who Developed Python Programming Language?
# Guido van Rossum
#
# 2.) Which type of programming does python support?
# Object-oriented programming and structured programming
#
# 3.) Is python case sensitive when deals with identifiers?
# Python is case sensitive when deals withs identifiers
#
# 4.) What is the correct extensions of the Python files
# .py
#
# 5.) Is Python code compiled or interpreted?
# python program is first compiled and then interpreted
#
# 6.) Name a few blocks of code used to define in Python Language?
# if statement block
# for loop block
# while loop block
# def function block
# class block
#
# 7.) State a character used to give single-line commment in python?
# Start from #.
#
# 8.) Mentions functions which can help us to find the version of python that we are currently working on?
# sys.version
# sys.version_info
# platform.python_version()
# platform.python_version_tuple()
# os.system('python --version')
#
# 9.) Python supports the creations of anonymous functions at runtime, using a construct called
# Lambda Functions
#
# 10.) What does pip stand for python?
# PIP stands for "Pip Installs Packages". It is the package installer for Python and is used to install and manage additional libraries and dependencies for Python packages.
#
# 11.) Mention a few built-in functions in python?
# print()
# len()
# type()
# range()
# input()
# list()
#
# 12.)What is the maximum possible length of an identifier in python?
# the maximum length of an identifier is not explicitly defined
#
# 13.) What are the benefits of using Python?
# Ease of use
# Large standard library
# cross-platform compatibillity
# Wide range of application
# open-source Community
# High Productivity
# Integration with other Languages
#
# 14.) How is memory managed in python?
# In Python, memory is managed automatically through a technique called "garbage collection".
#
#
#
# 16.) Is indentations required in python?
# yes

# %%
15.) How to install Python on Windows and set path variables?
To install Python on Windows and set up the necessary path variables, follow these steps:

Download Python:

Go to the official Python website at https://www.python.org/downloads/ and download the latest version of Python for Windows. Make sure to download the installer appropriate for your system, either 32-bit (x86) or 64-bit (x86-64).

Run the Installer:

Once the installer is downloaded, double-click on it to run it. You may need administrative privileges to install Python.

Customize Installation (Optional):

You will be presented with installation options. You can choose to customize the installation if you want to change the default settings or add optional features. However, for most users, the default settings are sufficient.

Install Python:

Click the "Install Now" button to start the installation process. Python will be installed in the default location, which is usually in the "C:\Program Files\Python" directory.

Add Python to PATH:

To use Python from the Command Prompt or PowerShell, you need to add Python to your system's PATH variable. Here's how you can do it:

During the installation, you will see an option called "Add Python X.X to PATH." Make sure to check this option before proceeding. This will automatically add Python to your PATH.

If you've already installed Python without adding it to the PATH, you can add it manually:

Open the Start menu and search for "Environment Variables" and select "Edit the system environment variables."
In the System Properties window, click the "Environment Variables" button.
In the Environment Variables window, under the "System variables" section, scroll down and find the "Path" variable. Select it and click the "Edit" button.
Click the "New" button and add the path to your Python installation directory. By default, it's something like "C:\Program Files\Python\PythonXX" (where XX is the version number).
Click "OK" to close all the windows.
Verify Installation:

Open Command Prompt or PowerShell and type the following command to verify that Python has been installed successfully:

css
Copy code
python --version
This command should display the installed Python version.

Install a Code Editor or IDE (Optional):

You may also want to install a code editor or integrated development environment (IDE) like Visual Studio Code, PyCharm, or IDLE to write and run Python code more easily.

That's it! Python should now be installed on your Windows system, and you can start using it for coding and scripting.
